# %% [markdown]
# <a href="https://colab.research.google.com/github/hkikura/colab_kadai/blob/main/%E8%AA%B2%E9%A1%8C1_kikura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [課題1]
# 　次のフローチャートのプログラムを書いてみましょう。
# 書き終わったら、GITHUB上に保存してください。
#
# ![flowchart1.jpg](data:image/jpeg;base64,...)

# %%
a = 3
b = 5
print(a * b)
# Out:
# 15
